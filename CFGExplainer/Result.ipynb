# %%
import matplotlib.pyplot as plt

# 準備要繪製的資料
x = [i for i in range(9)]
y = [0.0220, 0.0679, 0.3740, 0.1100, 0.0860, 0.2940, 0.2020, 0.3080, 0.9140]
part = [0.0220, 0.1180, 0.6660, 0.6680, 0.1360, 0.8820, 0.8620, 0.8940, 0.9580]
tri_part = [0.0220,0.7180, 0.9480, 0.9220, 0.7960, 0.9820, 0.9659, 0.9920, 1.0]  


# 創建圖形和軸
fig, ax = plt.subplots(figsize=(10, 8))  # 設置圖的大小，這裡為寬度8英寸，高度6英寸

# 繪製三條折線
ax.plot(x, y, label='Trigger')
# ax.plot(x, part, label='Trigger + Partition')
ax.plot(x, tri_part, label='Trigger + Trigger_Partition')

# 添加標籤和標題
ax.set_xlabel('Number of Subgraphs as Trigger')
ax.set_ylabel('Attack Success Rate(ASR)')
ax.set_title('Relationship between Number of Subgraphs and Attack Success Rate')

# 添加圖例
# ax.legend()

# 顯示圖形
plt.show()

# %%
import matplotlib.pyplot as plt

# 準備要繪製的資料
x = [i for i in range(9)]
y = [0.0220, 0.0679, 0.3740, 0.1100, 0.0860, 0.2940, 0.2020, 0.3080, 0.9140]
part = [0.0220, 0.0820, 0.1040, 0.0860, 0.0880, 0.1140, 0.1220, 0.0940, 0.4760]
tri_part = [0.0220, 0.6599, 0.8419, 0.8460, 0.5860, 0.8800, 0.8299, 0.8579, 0.8720]  


# 創建圖形和軸
fig, ax = plt.subplots(figsize=(10, 8))  # 設置圖的大小，這裡為寬度8英寸，高度6英寸

# 繪製三條折線
ax.plot(x, y, label='Trigger')
ax.plot(x, part, label='Partition')
# ax.plot(x, tri_part, label='Trigger_Partition')

# 添加標籤和標題
ax.set_xlabel('Number of Subgraphs as Trigger')
ax.set_ylabel('Attack Success Rate(ASR)')
ax.set_title('Attack success rate of Trigger Partition')

# 添加圖例
ax.legend()

# 顯示圖形
plt.show()

# %%
import matplotlib.pyplot as plt

# 準備要繪製的資料
x = [i for i in range(9)]
y = [0.0220, 0.0679, 0.3740, 0.1100, 0.0860, 0.2940, 0.2020, 0.3080, 0.9140]
part = [0.0220, 0.0820, 0.1040, 0.0860, 0.0880, 0.1140, 0.1220, 0.0940, 0.4760]
tri_part = [0.0220, 0.6599, 0.8419, 0.8460, 0.5860, 0.8800, 0.8299, 0.8579, 0.8720]  


# 創建圖形和軸
fig, ax = plt.subplots(figsize=(10, 8))  # 設置圖的大小，這裡為寬度8英寸，高度6英寸

# 繪製三條折線
# ax.plot(x, y, label='Trigger')
ax.plot(x, part, label='Partition')
ax.plot(x, tri_part, label='Trigger_Partition')

# 添加標籤和標題
ax.set_xlabel('Number of Subgraphs as Trigger')
ax.set_ylabel('Attack Success Rate(ASR)')
ax.set_title('ASR Relationship between Partition and Trigger Partition')

# 添加圖例
ax.legend()

# 顯示圖形
plt.show()

# %%
import matplotlib.pyplot as plt

# 準備要繪製的資料
x = [i for i in range(9)]
y = [0.0220, 0.0679, 0.3740, 0.1100, 0.0860, 0.2940, 0.2020, 0.3080, 0.9140]
part = [0.0220, 0.0820, 0.1040, 0.0860, 0.0880, 0.1140, 0.1220, 0.0940, 0.4760]
tri_part = [0.0220, 0.6599, 0.8419, 0.8460, 0.5860, 0.8800, 0.8299, 0.8579, 0.8720]  


# 創建圖形和軸
fig, ax = plt.subplots(figsize=(10, 8))  # 設置圖的大小，這裡為寬度8英寸，高度6英寸

# 繪製三條折線
ax.plot(x, y, label='Trigger')
ax.plot(x, part, label='Partition')
# ax.plot(x, tri_part, label='Trigger_Partition')

# 添加標籤和標題
ax.set_xlabel('Number of Subgraphs as Trigger')
ax.set_ylabel('Attack Success Rate(ASR)')
ax.set_title('Relationship between Number of Subgraphs and Attack Success Rate')

# 添加圖例
ax.legend()

# 顯示圖形
plt.show()
